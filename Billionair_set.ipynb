# %%
import pandas as pd

# %%
df = pd.read_csv("Billionaires_Dataset.csv")

# %%
df
# Out:
#    firstName    lastName  age  birthYear                     source  \
# 0       Jeff  Rothschild   68       1955                   Facebook
# 1      Tiger       Woods   47       1975                       Golf
# 2     LeBron       James   38       1984                 Basketball
# 3     Elaine        Wynn   80       1942            Casinos, hotels
# 4       Elon        Musk   51       1971              Tesla, SpaceX
# 5     Warren     Buffett   92       1930         Berkshire Hathaway
# 6    Michael   Bloomberg   81       1942               Bloomberg LP
# 7    Abigail     Johnson   61       1961                   Fidelity
# 8      David       Green   81       1941                     Retail
# 9    Michael       Rubin   50       1972              Online retail
# 10     James   Goodnight   80       1943                   Software
# 11      Mark      Walter   62       1960  Finance, asset management
# 12     Jimmy      Haslam   69       1954       Gas stations, retail
# ...

# %%
df.head()
# Out:
#   firstName    lastName  age  birthYear           source          industries  \
# 0      Jeff  Rothschild   68       1955         Facebook          Technology
# 1     Tiger       Woods   47       1975             Golf              Sports
# 2    LeBron       James   38       1984       Basketball              Sports
# 3    Elaine        Wynn   80       1942  Casinos, hotels  Gambling & Casinos
# 4      Elon        Musk   51       1971    Tesla, SpaceX          Automotive
#
#           title
# 0       Advisor
# 1       Athlete
# 2       Athlete
# 3  Board Member
# 4           CEO

# %%
df.describe()
# Out:
#              age    birthYear
# count  14.000000    14.000000
# mean   65.928571  1956.357143
# std    15.706267    15.544512
# min    38.000000  1930.000000
# 25%    53.500000  1942.250000
# 50%    65.500000  1957.000000
# 75%    80.000000  1968.500000
# max    92.000000  1984.000000
